# %% [markdown]
# # Contents <a id='back'></a>
#
# * [Introducción](#intro)
# * [Etapa 1. Descripción de los datos](#data_review)
#     * [Conclusiones](#data_review_conclusions)
# * [Etapa 2. Preprocesamiento de datos](#data_preprocessing)
#     * [2.1 Estilo del encabezado](#header_style)
#     * [2.2 Valores ausentes](#missing_values)
#     * [2.3 Duplicados](#duplicates)
#     * [2.4 Conclusiones](#data_preprocessing_conclusions)
# * [Etapa 3. Prueba de hipótesis](#hypothesis)
#     * [3.1 Hipótesis 1: actividad de los usuarios y las usuarias en las dos ciudades](#activity)
# * [Conclusiones](#end)

# %% [markdown]
# ## Introducción <a id='intro'></a>
# Como analista de datos, tu trabajo consiste en analizar datos para extraer información valiosa y tomar decisiones basadas en ellos. Esto implica diferentes etapas, como la descripción general de los datos, el preprocesamiento y la prueba de hipótesis.
#
# Siempre que investigamos, necesitamos formular hipótesis que después podamos probar. A veces aceptamos estas hipótesis; otras veces, las rechazamos. Para tomar las decisiones correctas, una empresa debe ser capaz de entender si está haciendo las suposiciones correctas.
#
# En este proyecto, compararás las preferencias musicales de las ciudades de Springfield y Shelbyville. Estudiarás datos reales de transmisión de música online para probar la hipótesis a continuación y comparar el comportamiento de los usuarios y las usuarias de estas dos ciudades.
#
# ### Objetivo:
# Prueba la hipótesis:
# 1. La actividad de los usuarios y las usuarias difiere según el día de la semana y dependiendo de la ciudad.
#
#
# ### Etapas
# Los datos del comportamiento del usuario se almacenan en el archivo `/datasets/music_project_en.csv`. No hay ninguna información sobre la calidad de los datos, así que necesitarás examinarlos antes de probar la hipótesis.
#
# Primero, evaluarás la calidad de los datos y verás si los problemas son significativos. Entonces, durante el preprocesamiento de datos, tomarás en cuenta los problemas más críticos.
#
# Tu proyecto consistirá en tres etapas:
#  1. Descripción de los datos.
#  2. Preprocesamiento de datos.
#  3. Prueba de hipótesis.

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# ## Etapa 1. Descripción de los datos <a id='data_review'></a>
#
# Abre los datos y examínalos.

# %% [markdown]
# Necesitarás `pandas`, así que impórtalo.

# %%
# Importar pandas
import pandas as pd #Le ponemos pd para abreviar el nombre
import plotly.express as px
import numpy as np

# %% [markdown]
# Lee el archivo `music_project_en.csv` de la carpeta `/datasets/` y guárdalo en la variable `df`:

# %%
# Leer el archivo y almacenarlo en df
df = pd.read_csv('music_project_en.csv')

# %% [markdown]
# Muestra las 10 primeras filas de la tabla:

# %%
# Obtener las 10 primeras filas de la tabla df
print(df.head(10))
# Out:
#      userID                        Track            artist   genre  \
# 0  FFB692EC            Kamigata To Boots  The Mass Missile    rock
# 1  55204538  Delayed Because of Accident  Andreas Rönnberg    rock
# 2    20EC38            Funiculì funiculà       Mario Lanza     pop
# 3  A3DD03C9        Dragons in the Sunset        Fire + Ice    folk
# 4  E2DC1FAE                  Soul People        Space Echo   dance
# 5  842029A1                       Chains          Obladaet  rusrap
# 6  4CB90AA5                         True      Roman Messer   dance
# 7  F03E1C1F             Feeling This Way   Polina Griffith   dance
# 8  8FA1D3BE                     L’estate       Julia Dalia  ruspop
# 9  E772D5C0                    Pessimist               NaN   dance
#
#         City        time        Day
# 0  Shelbyville  20:28:33  Wednesday
# 1  Springfield  14:07:09     Friday
# 2  Shelbyville  20:58:07  Wednesday
# 3  Shelbyville  08:37:09     Monday
# 4  Springfield  08:34:34     Monday
# 5  Shelbyville  13:09:41     Friday
# 6  Springfield  13:00:07  Wednesday
# 7  Springfield  20:47:49  Wednesday
# 8  Springfield  09:17:40     Friday
# 9  Shelbyville  21:20:49  Wednesday

# %% [markdown]
# Obtén la información general sobre la tabla con un comando. Conoces el método que muestra la información general que necesitamos.

# %%
# Obtener la información general sobre nuestros datos
print(df.describe()) #Ver datos estadisticos generales de los datos
print()
print(df.info()) #Ver informacion general del dataframe
print()
print(df.shape) #Ver como estan organizados los datos
# Out:
#           userID  Track     artist  genre       City        time     Day
# count      65079  63736      57512  63881        65079     65079   65079
# unique     41748  39666      37806    268            2     20392       3
# top     A8AE9169  Brand  Kartvelli    pop  Springfield  08:14:07  Friday
# freq          76    136        136   8850        45360        14   23149
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65079 entries, 0 to 65078
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0     userID  65079 non-null  object
#  1   Track     63736 non-null  object
#  2   artist    57512 non-null  object
#  3   genre     63881 non-null  object
#  4     City    65079 non-null  object
#  5   time      65079 non-null  object
#  6   Day       65079 non-null  object
# dtypes: object(7)
# memory usage: 3.5+ MB
# None
#
# (65079, 7)

# %% [markdown]
# Estas son nuestras observaciones sobre la tabla. Contiene siete columnas. Almacenan los mismos tipos de datos: `object`.
#
# Según la documentación:
# - `' userID'`: identificador del usuario o la usuaria;
# - `'Track'`: título de la canción;
# - `'artist'`: nombre del artista;
# - `'genre'`: género de la pista;
# - `'City'`: ciudad del usuario o la usuaria;
# - `'time'`: la hora exacta en la que se reprodujo la canción;
# - `'Day'`: día de la semana.
#
# Podemos ver tres problemas con el estilo en los encabezados de la tabla:
# 1. Algunos encabezados están en mayúsculas, otros en minúsculas.
# 2. Hay espacios en algunos encabezados.
# 3. `En lugar de " userID" se podria usar snake case y de esta manera quedaria "user_id"`.

# %% [markdown]
# ### Escribe observaciones de tu parte. Estas son algunas de las preguntas que pueden ser útiles: <a id='data_review_conclusions'></a>
#
# `1.   ¿Qué tipo de datos tenemos a nuestra disposición en las filas? ¿Y cómo podemos entender lo que almacenan las columnas? tenemos datos de tipo objeto, y se puede saber que almacenan las columnas ya sea leyendo la documentacion del dataset o imprimiendo parte de los datos.`
#
# `2.   ¿Hay suficientes datos para proporcionar respuestas a nuestra hipótesis o necesitamos más información? Si, ya que tenemos datos sobre los dias y la ciudad`
#
# `3.   ¿Notaste algún problema en los datos, como valores ausentes, duplicados o tipos de datos incorrectos? Si, las cantidades de datos en algunas columnas difieren con otras lo que en un principio puede sugerir que hay algunos valores ausentes`

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# ## Etapa 2. Preprocesamiento de datos <a id='data_preprocessing'></a>
#
# El objetivo aquí es preparar los datos para que sean analizados.
# El primer paso es resolver cualquier problema con los encabezados. Luego podemos avanzar a los valores ausentes y duplicados. Empecemos.
#
# Corrige el formato en los encabezados de la tabla.

# %% [markdown]
# ### Estilo del encabezado <a id='header_style'></a>
# Muestra los encabezados de la tabla (los nombres de las columnas):

# %%
# Muestra los nombres de las columnas
print(df.columns)
# Out:
# Index(['  userID', 'Track', 'artist', 'genre', '  City  ', 'time', 'Day'], dtype='object')

# %% [markdown]
# Cambia los encabezados de la tabla de acuerdo con las reglas del buen estilo:
# * Todos los caracteres deben ser minúsculas.
# * Elimina los espacios.
# * Si el nombre tiene varias palabras, utiliza snake_case.

# %% [markdown]
# Anteriormente, aprendiste acerca de la forma automática de cambiar el nombre de las columnas. Vamos a aplicarla ahora. Utiliza el bucle for para iterar sobre los nombres de las columnas y poner todos los caracteres en minúsculas. Cuando hayas terminado, vuelve a mostrar los encabezados de la tabla:

# %%
# Bucle en los encabezados poniendo todo en minúsculas
new_col_names = [] #Creamos una lista donde se van a almacenar los nombres de las columnas modificados
for old_columns in df.columns: #Declaramos un bucle for que va a iterar en las columnas del dataframe
    new = old_columns.lower() #Utilizamos el comando lower para poner la variable en minuscula y la guardamos en una nueva variable
    new_col_names.append(new) #Agregamos las variables modificadas a nuestra lista
df.columns = new_col_names #Reemplazamos los nombres de las columnas 
print(df.columns) #Mostramos las columnas
# Out:
# Index(['  userid', 'track', 'artist', 'genre', '  city  ', 'time', 'day'], dtype='object')

# %% [markdown]
# Ahora, utilizando el mismo método, elimina los espacios al principio y al final de los nombres de las columnas e imprime los nombres de las columnas nuevamente:

# %%
# Bucle en los encabezados eliminando los espacios
new_col_names = [] #Creamos una lista donde se van a almacenar los nombres de las columnas modificados
for old_columns in df.columns: #Declaramos un bucle for que va a iterar en las columnas del dataframe
    new = old_columns.strip() #Utilizamos el comando strip para eliminar los espacios y la guardamos en una nueva variable
    new_col_names.append(new) #Agregamos las variables modificadas a nuestra lista
df.columns = new_col_names #Reemplazamos los nombres de las columnas 
print(df.columns) #Mostramos las columnas
# Out:
# Index(['userid', 'track', 'artist', 'genre', 'city', 'time', 'day'], dtype='object')

# %% [markdown]
# Necesitamos aplicar la regla de snake_case a la columna `userid`. Debe ser `user_id`. Cambia el nombre de esta columna y muestra los nombres de todas las columnas cuando hayas terminado.

# %%
# Cambiar el nombre de la columna "userid"
columns_new = {"userid": "user_id"} #Definimos como un diccionario los nombres antiguo y nuevo de la columna que deseamos reemplazar
df.rename(columns = columns_new, inplace = True) #LLamamos al metodo rename para reemplazar el nombre de la columna

# %% [markdown]
# Comprueba el resultado. Muestra los encabezados una vez más:

# %%
# Comprobar el resultado: la lista de encabezados
print(df.columns)
# Out:
# Index(['user_id', 'track', 'artist', 'genre', 'city', 'time', 'day'], dtype='object')

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# ### Valores ausentes <a id='missing_values'></a>
#  Primero, encuentra el número de valores ausentes en la tabla. Debes utilizar dos métodos en una secuencia para obtener el número de valores ausentes.

# %%
print(df.isna())
# Out:
#        user_id  track  artist  genre   city   time    day
# 0        False  False   False  False  False  False  False
# 1        False  False   False  False  False  False  False
# 2        False  False   False  False  False  False  False
# 3        False  False   False  False  False  False  False
# 4        False  False   False  False  False  False  False
# ...        ...    ...     ...    ...    ...    ...    ...
# 65074    False  False   False  False  False  False  False
# 65075    False  False   False  False  False  False  False
# 65076    False  False    True  False  False  False  False
# 65077    False  False   False  False  False  False  False
# 65078    False  False   False  False  False  False  False
#
# [65079 rows x 7 columns]

# %%
# Calcular el número de valores ausentes
print(df.isna().sum()) #Llamamos al metodo isna para comprobar valores ausentes y a sum para obtener el conteo
# Out:
# user_id       0
# track      1343
# artist     7567
# genre      1198
# city          0
# time          0
# day           0
# dtype: int64

# %% [markdown]
# No todos los valores ausentes afectan a la investigación. Por ejemplo, los valores ausentes en `track` y `artist` no son cruciales. Simplemente puedes reemplazarlos con valores predeterminados como el string `'unknown'` (desconocido).
#
# Pero los valores ausentes en `'genre'` pueden afectar la comparación entre las preferencias musicales de Springfield y Shelbyville. En la vida real, sería útil saber las razones por las cuales hay datos ausentes e intentar recuperarlos. Pero no tenemos esa oportunidad en este proyecto. Así que tendrás que:
# * rellenar estos valores ausentes con un valor predeterminado;
# * evaluar cuánto podrían afectar los valores ausentes a tus cómputos;

# %% [markdown]
# Reemplazar los valores ausentes en las columnas `'track'`, `'artist'` y `'genre'` con el string `'unknown'`. Como mostramos anteriormente en las lecciones, la mejor forma de hacerlo es crear una lista que almacene los nombres de las columnas donde se necesita el reemplazo. Luego, utiliza esta lista e itera sobre las columnas donde se necesita el reemplazo haciendo el propio reemplazo.

# %%
# Bucle en los encabezados reemplazando los valores ausentes con 'unknown'
columns_to_replace = ['track', 'artist' , 'genre'] #Declaramos los nombres de las columnas en las cuales deseamos reemplazar el contenido vacio 
for col in columns_to_replace: #iteramos en las columnas que se van a reemplazar los datos vacios
    df[col].fillna('unknown', inplace = True) #rellenamos los datos vacios con la palabra 'unknown'

# %% [markdown]
# Ahora comprueba el resultado para asegurarte de que después del reemplazo no haya valores ausentes en el conjunto de datos. Para hacer esto, cuenta los valores ausentes nuevamente.

# %%
# Contar valores ausentes
print(df.isna().sum())
# Out:
# user_id    0
# track      0
# artist     0
# genre      0
# city       0
# time       0
# day        0
# dtype: int64

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# ### Duplicados <a id='duplicates'></a>
# Encuentra el número de duplicados explícitos en la tabla. Una vez más, debes aplicar dos métodos en una secuencia para obtener la cantidad de duplicados explícitos.

# %%
print(df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 65074    False
# 65075    False
# 65076    False
# 65077    False
# 65078    False
# Length: 65079, dtype: bool

# %%
# Contar duplicados explícitos
print(df.duplicated().sum())
# Out:
# 3826

# %% [markdown]
# Ahora, elimina todos los duplicados. Para ello, llama al método que hace exactamente esto.

# %%
# Eliminar duplicados explícitos
df = df.drop_duplicates().reset_index(drop = True) #Eliminamos los datos duplicados y reiniciamos los indices

# %% [markdown]
# Comprobemos ahora si eliminamos con éxito todos los duplicados. Cuenta los duplicados explícitos una vez más para asegurarte de haberlos eliminado todos:

# %%
# Comprobar de nuevo si hay duplicados
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Ahora queremos deshacernos de los duplicados implícitos en la columna `genre`. Por ejemplo, el nombre de un género se puede escribir de varias formas. Dichos errores también pueden afectar al resultado.

# %% [markdown]
# Para hacerlo, primero mostremos una lista de nombres de género únicos, ordenados en orden alfabético. Para ello:
# * Extrae la columna `genre` del DataFrame.
# * Llama al método que devolverá todos los valores únicos en la columna extraída.

# %%
# Inspeccionar los nombres de géneros únicos
df_ordenado = df.sort_values(by='genre') #ordenamos los datos por genero en un nuevo dataframe
print(df_ordenado['genre'].unique()) #imprimimos los valores unicos de la columna 'genre'
# Out:
# ['acid' 'acoustic' 'action' 'adult' 'africa' 'afrikaans' 'alternative'
#  'ambient' 'americana' 'animated' 'anime' 'arabesk' 'arabic' 'arena'
#  'argentinetango' 'art' 'audiobook' 'avantgarde' 'axé' 'baile' 'balkan'
#  'beats' 'bigroom' 'black' 'bluegrass' 'blues' 'bollywood' 'bossa'
#  'brazilian' 'breakbeat' 'breaks' 'broadway' 'cantautori' 'cantopop'
#  'canzone' 'caribbean' 'caucasian' 'celtic' 'chamber' 'children' 'chill'
#  'chinese' 'choral' 'christian' 'christmas' 'classical' 'classicmetal'
#  'club' 'colombian' 'comedy' 'conjazz' 'contemporary' 'country' 'cuban'
#  'dance' 'dancehall' 'dancepop' 'dark' 'death' 'deep' 'deutschrock'
#  'deutschspr' 'dirty' 'disco' 'dnb' 'documentary' 'downbeat' 'downtempo'
#  'drum' 'dub' 'dubstep' 'eastern' 'easy' 'electronic' 'electropop' 'emo'
#  'entehno' 'epicmetal' 'estrada' 'ethnic' 'eurofolk' 'european'
#  'experimental' 'extrememetal' 'fado' 'film' 'fitness' 'flamenco' 'folk'
#  'folklore' 'folkmetal' 'folkrock' 'folktronica' 'forró' 'frankreich'
#  'französisch' 'french' 'funk' 'future' 'gangsta' 'garage' 'german'
#  'ghazal' 'gitarre' 'glitch' 'gospel' 'gothic' 'grime' 'grunge' 'gypsy'
#  'handsup' "hard'n'heavy" 'hardcore' 'hardstyle' 'hardtechno' 'hip'
#  'hip-hop' 'hiphop' 'historisch' 'holiday' 'hop' 'horror' 'house' 'idm'
#  'independent' 'indian' 'indie' 'indipop' 'industrial' 'inspirational'
#  'instrumental' 'international' 'irish' 'jam' 'japanese' 'jazz' 'jewish'
#  'jpop' 'jungle' 'k-pop' 'karadeniz' 'karaoke' 'kayokyoku' 'korean'
#  'laiko' 'latin' 'latino' 'leftfield' 'local' 'lounge' 'loungeelectronic'
#  'lovers' 'malaysian' 'mandopop' 'marschmusik' 'meditative'
#  'mediterranean' 'melodic' 'metal' 'metalcore' 'mexican' 'middle'
#  'minimal' 'miscellaneous' 'modern' 'mood' 'mpb' 'muslim' 'native'
#  'neoklassik' 'neue' 'new' 'newage' 'newwave' 'nu' 'nujazz' 'numetal'
#  'oceania' 'old' 'opera' 'orchestral' 'other' 'piano' 'pop'
#  'popelectronic' 'popeurodance' 'post' 'posthardcore' 'postrock' 'power'
#  'progmetal' 'progressive' 'psychedelic' 'punjabi' 'punk' 'quebecois'
#  'ragga' 'ram' 'rancheras' 'rap' 'rave' 'reggae' 'reggaeton' 'regional'
#  'relax' 'religious' 'retro' 'rhythm' 'rnb' 'rnr' 'rock' 'rockabilly'
#  'romance' 'roots' 'ruspop' 'rusrap' 'rusrock' 'salsa' 'samba' 'schlager'
#  'self' 'sertanejo' 'shoegazing' 'showtunes' 'singer' 'ska' 'slow'
#  'smooth' 'soul' 'soulful' 'sound' 'soundtrack' 'southern' 'specialty'
#  'speech' 'spiritual' 'sport' 'stonerrock' 'surf' 'swing' 'synthpop'
#  'sängerportrait' 'tango' 'tanzorchester' 'taraftar' 'tech' 'techno'
#  'thrash' 'top' 'traditional' 'tradjazz' 'trance' 'tribal' 'trip'
#  'triphop' 'tropical' 'türk' 'türkçe' 'unknown' 'urban' 'uzbek' 'variété'
#  'vi' 'videogame' 'vocal' 'western' 'world' 'worldbeat' 'ïîï']

# %%
print(sorted(df['genre'].unique()))
# Out:
# ['acid', 'acoustic', 'action', 'adult', 'africa', 'afrikaans', 'alternative', 'ambient', 'americana', 'animated', 'anime', 'arabesk', 'arabic', 'arena', 'argentinetango', 'art', 'audiobook', 'avantgarde', 'axé', 'baile', 'balkan', 'beats', 'bigroom', 'black', 'bluegrass', 'blues', 'bollywood', 'bossa', 'brazilian', 'breakbeat', 'breaks', 'broadway', 'cantautori', 'cantopop', 'canzone', 'caribbean', 'caucasian', 'celtic', 'chamber', 'children', 'chill', 'chinese', 'choral', 'christian', 'christmas', 'classical', 'classicmetal', 'club', 'colombian', 'comedy', 'conjazz', 'contemporary', 'country', 'cuban', 'dance', 'dancehall', 'dancepop', 'dark', 'death', 'deep', 'deutschrock', 'deutschspr', 'dirty', 'disco', 'dnb', 'documentary', 'downbeat', 'downtempo', 'drum', 'dub', 'dubstep', 'eastern', 'easy', 'electronic', 'electropop', 'emo', 'entehno', 'epicmetal', 'estrada', 'ethnic', 'eurofolk', 'european', 'experimental', 'extrememetal', 'fado', 'film', 'fitness', 'flamenco', 'folk', 'folklore', 'folkmetal', 'folkrock', 'folktronica', 'forró', 'frankreich', 'französisch', 'french', 'funk', 'future', 'gangsta', 'garage', 'german', 'ghazal', 'gitarre', 'glitch', 'gospel', 'gothic', 'grime', 'grunge', 'gypsy', 'handsup', "hard'n'heavy", 'hardcore', 'hardstyle', 'hardtechno', 'hip', 'hip-hop', 'hiphop', 'historisch', 'holiday', 'hop', 'horror', 'house', 'idm', 'independent', 'indian', 'indie', 'indipop', 'industrial', 'inspirational', 'instrumental', 'international', 'irish', 'jam', 'japanese', 'jazz', 'jewish', 'jpop', 'jungle', 'k-pop', 'karadeniz', 'karaoke', 'kayokyoku', 'korean', 'laiko', 'latin', 'latino', 'leftfield', 'local', 'lounge', 'loungeelectronic', 'lovers', 'malaysian', 'mandopop', 'marschmusik', 'meditative', 'mediterranean', 'melodic', 'metal', 'metalcore', 'mexican', 'middle', 'minimal', 'miscellaneous', 'modern', 'mood', 'mpb', 'muslim', 'native', 'neoklassik', 'neue', 'new', 'newage', 'newwave', 'nu', 'nujazz', 'numetal', 'oceania', 'old', 'opera', 'orchestral', 'other', 'piano', 'pop', 'popelectronic', 'popeurodance', 'post', 'posthardcore', 'postrock', 'power', 'progmetal', 'progressive', 'psychedelic', 'punjabi', 'punk', 'quebecois', 'ragga', 'ram', 'rancheras', 'rap', 'rave', 'reggae', 'reggaeton', 'regional', 'relax', 'religious', 'retro', 'rhythm', 'rnb', 'rnr', 'rock', 'rockabilly', 'romance', 'roots', 'ruspop', 'rusrap', 'rusrock', 'salsa', 'samba', 'schlager', 'self', 'sertanejo', 'shoegazing', 'showtunes', 'singer', 'ska', 'slow', 'smooth', 'soul', 'soulful', 'sound', 'soundtrack', 'southern', 'specialty', 'speech', 'spiritual', 'sport', 'stonerrock', 'surf', 'swing', 'synthpop', 'sängerportrait', 'tango', 'tanzorchester', 'taraftar', 'tech', 'techno', 'thrash', 'top', 'traditional', 'tradjazz', 'trance', 'tribal', 'trip', 'triphop', 'tropical', 'türk', 'türkçe', 'unknown', 'urban', 'uzbek', 'variété', 'vi', 'videogame', 'vocal', 'western', 'world', 'worldbeat', 'ïîï']

# %% [markdown]
# Africa y Afrikaans, animated y anime, arabesk y arabic, latin y latino, nu y numetal, tango y argentinetango, türk y türkçe

# %% [markdown]
# Busca en la lista para encontrar duplicados implícitos del género `hiphop`. Estos pueden ser nombres escritos incorrectamente o nombres alternativos para el mismo género.
#
# Verás los siguientes duplicados implícitos:
# * `hip`
# * `hop`
# * `hip-hop`
#
# Para deshacerte de ellos, crea una función llamada `replace_wrong_genres()` con dos parámetros:
# * `wrong_genres=`: esta es una lista que contiene todos los valores que necesitas reemplazar.
# * `correct_genre=`: este es un string que vas a utilizar como reemplazo.
#
# Como resultado, la función debería corregir los nombres en la columna `'genre'` de la tabla `df`, es decir, remplazar cada valor de la lista `wrong_genres` por el valor en `correct_genre`.
#
# Dentro del cuerpo de la función, utiliza un bucle `'for'` para iterar sobre la lista de géneros incorrectos, extrae la columna `'genre'` y aplica el método `replace` para hacer correcciones.

# %%
# Función para reemplazar duplicados implícitos
def replace_wrong_genres(wrong_genres, correct_genre):
    for wrong_genre in wrong_genres:
        df['genre'].replace(wrong_genres, correct_genre, inplace = True)
    return df

# %% [markdown]
# Ahora, llama a `replace_wrong_genres()` y pásale tales argumentos para que retire los duplicados implícitos (`hip`, `hop` y `hip-hop`) y los reemplace por `hiphop`:

# %%
# Eliminar duplicados implícitos
replace_wrong_genres(['hip', 'hop', 'hip-hop'],'hiphop')
replace_wrong_genres(['africa'],'afrikaans')
replace_wrong_genres(['arabesk'],'arabic')
replace_wrong_genres(['latino'],'latin')
replace_wrong_genres(['nu'],'numetal')
replace_wrong_genres(['argentinetango'],'tango')
# Out:
#         user_id                              track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 61248  729CBB09                            My Name            McLean
# 61249  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 61250  C5E3A0D5                          Jalopiina           unknown
# 61251  321D0506                      Freight Train     Chas McDevitt
# 61252  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre         city      time        day
# 0            rock  Shelbyville  20:28:33  Wednesday
# 1            rock  Springfield  14:07:09     Friday
# 2             pop  Shelbyville  20:58:07  Wednesday
# 3            folk  Shelbyville  08:37:09     Monday
# 4           dance  Springfield  08:34:34     Monday
# ...           ...          ...       ...        ...
# 61248         rnb  Springfield  13:32:28  Wednesday
# 61249      hiphop  Shelbyville  10:00:00     Monday
# 61250  industrial  Springfield  20:09:26     Friday
# 61251        rock  Springfield  21:43:59     Friday
# 61252     country  Springfield  21:59:46     Friday
#
# [61253 rows x 7 columns]

# %% [markdown]
# Asegúrate de que los nombres duplicados han sido eliminados. Muestra la lista de valores únicos de la columna `'genre'` una vez más:

# %%
# Comprobación de duplicados implícitos
df_ordenado2 = df.sort_values(by='genre') #ordenamos los datos por genero en un nuevo dataframe
print(df_ordenado2['genre'].unique()) #imprimimos los valores unicos de la columna 'genre'
# Out:
# ['acid' 'acoustic' 'action' 'adult' 'afrikaans' 'alternative' 'ambient'
#  'americana' 'animated' 'anime' 'arabic' 'arena' 'art' 'audiobook'
#  'avantgarde' 'axé' 'baile' 'balkan' 'beats' 'bigroom' 'black' 'bluegrass'
#  'blues' 'bollywood' 'bossa' 'brazilian' 'breakbeat' 'breaks' 'broadway'
#  'cantautori' 'cantopop' 'canzone' 'caribbean' 'caucasian' 'celtic'
#  'chamber' 'children' 'chill' 'chinese' 'choral' 'christian' 'christmas'
#  'classical' 'classicmetal' 'club' 'colombian' 'comedy' 'conjazz'
#  'contemporary' 'country' 'cuban' 'dance' 'dancehall' 'dancepop' 'dark'
#  'death' 'deep' 'deutschrock' 'deutschspr' 'dirty' 'disco' 'dnb'
#  'documentary' 'downbeat' 'downtempo' 'drum' 'dub' 'dubstep' 'eastern'
#  'easy' 'electronic' 'electropop' 'emo' 'entehno' 'epicmetal' 'estrada'
#  'ethnic' 'eurofolk' 'european' 'experimental' 'extrememetal' 'fado'
#  'film' 'fitness' 'flamenco' 'folk' 'folklore' 'folkmetal' 'folkrock'
#  'folktronica' 'forró' 'frankreich' 'französisch' 'french' 'funk' 'future'
#  'gangsta' 'garage' 'german' 'ghazal' 'gitarre' 'glitch' 'gospel' 'gothic'
#  'grime' 'grunge' 'gypsy' 'handsup' "hard'n'heavy" 'hardcore' 'hardstyle'
#  'hardtechno' 'hiphop' 'historisch' 'holiday' 'horror' 'house' 'idm'
#  'independent' 'indian' 'indie' 'indipop' 'industrial' 'inspirational'
#  'instrumental' 'international' 'irish' 'jam' 'japanese' 'jazz' 'jewish'
#  'jpop' 'jungle' 'k-pop' 'karadeniz' 'karaoke' 'kayokyoku' 'korean'
#  'laiko' 'latin' 'leftfield' 'local' 'lounge' 'loungeelectronic' 'lovers'
#  'malaysian' 'mandopop' 'marschmusik' 'meditative' 'mediterranean'
#  'melodic' 'metal' 'metalcore' 'mexican' 'middle' 'minimal'
#  'miscellaneous' 'modern' 'mood' 'mpb' 'muslim' 'native' 'neoklassik'
#  'neue' 'new' 'newage' 'newwave' 'nujazz' 'numetal' 'oceania' 'old'
#  'opera' 'orchestral' 'other' 'piano' 'pop' 'popelectronic' 'popeurodance'
#  'post' 'posthardcore' 'postrock' 'power' 'progmetal' 'progressive'
#  'psychedelic' 'punjabi' 'punk' 'quebecois' 'ragga' 'ram' 'rancheras'
#  'rap' 'rave' 'reggae' 'reggaeton' 'regional' 'relax' 'religious' 'retro'
#  'rhythm' 'rnb' 'rnr' 'rock' 'rockabilly' 'romance' 'roots' 'ruspop'
#  'rusrap' 'rusrock' 'salsa' 'samba' 'schlager' 'self' 'sertanejo'
#  'shoegazing' 'showtunes' 'singer' 'ska' 'slow' 'smooth' 'soul' 'soulful'
#  'sound' 'soundtrack' 'southern' 'specialty' 'speech' 'spiritual' 'sport'
#  'stonerrock' 'surf' 'swing' 'synthpop' 'sängerportrait' 'tango'
#  'tanzorchester' 'taraftar' 'tech' 'techno' 'thrash' 'top' 'traditional'
#  'tradjazz' 'trance' 'tribal' 'trip' 'triphop' 'tropical' 'türk' 'türkçe'
#  'unknown' 'urban' 'uzbek' 'variété' 'vi' 'videogame' 'vocal' 'western'
#  'world' 'worldbeat' 'ïîï']

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# ### Tus observaciones <a id='data_preprocessing_conclusions'></a>
#
# `Describe brevemente lo que has notado al analizar duplicados, cómo abordaste sus eliminaciones y qué resultados obtuviste.
# Primero habian muchos duplicados explicitos los cuales son faciles de eliminar llamando al metodo drop_duplicates(), los mas complejos son los duplicados implicitos ya que tenemos que analizar que datos guardan similitudes unos con los otros y categorizarlos nuevamente en una sola categoria, para ello es mas facil ordenar alfabeticamente el tipo de datos del cual queremos encontrar similitudes ya que a veces el mismo dato esta escrito de diferentes maneras pero suelen iniciar con la misma letra, lo cual facilita el trabajo de encontrar esos valores duplicados y una vez identificados se puede definir una funcion para reemplzaar esos valores con el valor correcto`

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# ## Etapa Adicional. Steven <a id='hypothesis'></a>

# %%
#vamos a ver los datos de que dias tenemos
print(df['day'].unique())
print(df['city'].unique())
print(df.head())
df['time'] = pd.to_datetime(df['time'], format='%H:%M:%S').dt.time
# Out:
# ['Wednesday' 'Friday' 'Monday']
# ['Shelbyville' 'Springfield']
#     user_id                        track            artist  genre  \
# 0  FFB692EC            Kamigata To Boots  The Mass Missile   rock
# 1  55204538  Delayed Because of Accident  Andreas Rönnberg   rock
# 2    20EC38            Funiculì funiculà       Mario Lanza    pop
# 3  A3DD03C9        Dragons in the Sunset        Fire + Ice   folk
# 4  E2DC1FAE                  Soul People        Space Echo  dance
#
#           city      time        day
# 0  Shelbyville  20:28:33  Wednesday
# 1  Springfield  14:07:09     Friday
# 2  Shelbyville  20:58:07  Wednesday
# 3  Shelbyville  08:37:09     Monday
# 4  Springfield  08:34:34     Monday

# %%
df['hour'] = pd.to_datetime(df['time'], format='%H:%M:%S').dt.hour
df = df.sort_values(by='hour', ascending=True)
print(df.head())
# Out:
#         user_id               track                  artist    genre  \
# 21749   B40014C  We Could Be Better  Janine And The Mixtape      rnb
# 28939  625BE1A0       I Want It All    Minutes Til Midnight     rock
# 36712  15FFAC16             unknown                 unknown  unknown
# 28943  3EE63103           Klekánice                 unknown     jazz
# 36709  495C52A5         Rocking Now                 unknown    dance
#
#               city      time        day  hour
# 21749  Springfield  08:40:54     Friday     8
# 28939  Springfield  08:53:54  Wednesday     8
# 36712  Shelbyville  08:44:21  Wednesday     8
# 28943  Springfield  08:16:29     Friday     8
# 36709  Shelbyville  08:25:27     Monday     8

# %%
listeners_per_day = df.groupby('day')['user_id'].count().reset_index()
listeners_per_day.rename(columns={'user_id':'listeners'},inplace=True)
print(listeners_per_day)
# Out:
#          day  listeners
# 0     Friday      21840
# 1     Monday      21354
# 2  Wednesday      18059

# %%
#Gráfico de barras interactivo
fig = px.bar(listeners_per_day, x='day', y='listeners', title="Listeners per day", 
             labels={'listeners': 'Total listeners'}, 
             color='day')
fig.show()

# %%
listeners_per_city= df.groupby('city')['user_id'].count().reset_index()
listeners_per_city.rename(columns={'user_id':'listeners'},inplace=True)
print(listeners_per_city)
# Out:
#           city  listeners
# 0  Shelbyville      18512
# 1  Springfield      42741

# %%
#Gráfico de barras interactivo
fig = px.bar(listeners_per_city, x='city', y='listeners', title="Listeners per city", 
             labels={'listeners': 'Total listeners'}, 
             color='city')
fig.show()

# %%
listeners_per_city_per_day = df.groupby(['city','day'])['user_id'].count().reset_index()
listeners_per_city_per_day.rename(columns={'user_id':'listeners'},inplace=True)
print(listeners_per_city_per_day)
# Out:
#           city        day  listeners
# 0  Shelbyville     Friday       5895
# 1  Shelbyville     Monday       5614
# 2  Shelbyville  Wednesday       7003
# 3  Springfield     Friday      15945
# 4  Springfield     Monday      15740
# 5  Springfield  Wednesday      11056

# %%
fig = px.bar(
    listeners_per_city_per_day,  # DataFrame con los datos
    x='day',                     # Eje X: los días de la semana
    y='listeners',               # Eje Y: la cantidad de oyentes
    color='city',                # Color por ciudad para diferenciar las barras
    labels={'listeners': 'Cantidad de Oyentes', 'day': 'Día de la Semana'},
    title='Comparación de Oyentes por Día en Cada Ciudad',
    barmode='group'              # Para que las barras se agrupan por ciudad
)
# Mostrar el gráfico
fig.show()

# %%
fig = px.bar(
    listeners_per_city_per_day,  # DataFrame con los datos
    x='city',                     # Eje X: los días de la semana
    y='listeners',               # Eje Y: la cantidad de oyentes
    color='day',                # Color por ciudad para diferenciar las barras
    labels={'listeners': 'Cantidad de Oyentes', 'day': 'Día de la Semana'},
    title='Comparación de Oyentes por Día en Cada Ciudad',
    barmode='group'              # Para que las barras se agrupan por ciudad
)
# Mostrar el gráfico
fig.show()

# %%
import plotly.express as px

# Crear el gráfico de barras apiladas
fig = px.bar(
    listeners_per_city_per_day,  # DataFrame con los datos
    x='day',                    # Eje X: las ciudades
    y='listeners',               # Eje Y: la cantidad de oyentes
    color='city',                 # Diferenciar por día
    labels={'listeners': 'Cantidad de Oyentes', 'city': 'Ciudad'},
    title='Escuchas por Ciudad con Distribución por Día',
    barmode='stack'              # Para apilar las barras
)

# Mostrar el gráfico
fig.show()

# %%
# Asegurar que 'hour' es un número entero
df['hour'] = df['hour'].astype(int)
# Agrupar por día de la semana y hora, contando las escuchas
df_grouped = df.groupby(['day', 'hour'])['user_id'].count().reset_index()
# Renombrar la columna de conteo
df_grouped.rename(columns={'user_id': 'listeners'}, inplace=True)

# %%
print(df_grouped)
# Out:
#           day  hour  listeners
# 0      Friday     8       3572
# 1      Friday     9       3575
# 2      Friday    10         72
# 3      Friday    13       3515
# 4      Friday    14       3682
# 5      Friday    15         64
# 6      Friday    20       3788
# 7      Friday    21       3509
# 8      Friday    22         63
# 9      Monday     8       3438
# 10     Monday     9       3375
# 11     Monday    10         50
# 12     Monday    13       3512
# 13     Monday    14       3696
# 14     Monday    15         62
# 15     Monday    20       3794
# 16     Monday    21       3367
# 17     Monday    22         60
# 18  Wednesday     8       2502
# 19  Wednesday     9       2561
# 20  Wednesday    10         47
# 21  Wednesday    13       3277
# 22  Wednesday    14       3344
# 23  Wednesday    15         50
# 24  Wednesday    20       3247
# 25  Wednesday    21       2982
# 26  Wednesday    22         49

# %%
# Crear el gráfico de líneas
fig = px.line(df_grouped, x='hour', y='listeners', color='day',
              labels={'listeners': 'Cantidad de Oyentes', 'hour': 'Hora del Día'},
              title='Evolución de Oyentes a lo Largo del Día por Día de la Semana',
              markers=True)
# Ajustar el eje X para que muestre cada hora correctamente
fig.update_xaxes(tickmode='linear', dtick=1)
# Mostrar el gráfico
fig.show()

# %%
# Agrupar por día de la semana y hora, contando las escuchas
df_grouped2 = df.groupby(['city','hour'])['user_id'].count().reset_index()
# Renombrar la columna de conteo
df_grouped2.rename(columns={'user_id': 'listeners'}, inplace=True)

# %%
print(df_grouped2)
# Out:
#            city  hour  listeners
# 0   Shelbyville     8       2640
# 1   Shelbyville     9       2709
# 2   Shelbyville    10         42
# 3   Shelbyville    13       3174
# 4   Shelbyville    14       3415
# 5   Shelbyville    15         49
# 6   Shelbyville    20       3297
# 7   Shelbyville    21       3128
# 8   Shelbyville    22         58
# 9   Springfield     8       6872
# 10  Springfield     9       6802
# 11  Springfield    10        127
# 12  Springfield    13       7130
# 13  Springfield    14       7307
# 14  Springfield    15        127
# 15  Springfield    20       7532
# 16  Springfield    21       6730
# 17  Springfield    22        114

# %%
# Crear el gráfico de líneas
fig = px.line(df_grouped2, x='hour', y='listeners', color='city',
              labels={'listeners': 'Cantidad de Oyentes', 'hour': 'Hora del Día'},
              title='Evolución de Oyentes a lo Largo del Día por Ciudad',
              markers=True)
# Ajustar el eje X para que muestre cada hora correctamente
fig.update_xaxes(tickmode='linear', dtick=1)
# Mostrar el gráfico
fig.show()

# %%
listeners_per_genre= df.groupby('genre')['user_id'].count().reset_index()
listeners_per_genre.rename(columns={'user_id': 'listeners'}, inplace=True)
listeners_per_genre= listeners_per_genre.sort_values('listeners', ascending=False).reset_index()
listeners_per_genre = listeners_per_genre.drop(columns=['index'])
print(listeners_per_genre.head(10))
# Out:
#          genre  listeners
# 0          pop       8323
# 1        dance       6367
# 2         rock       5844
# 3   electronic       5522
# 4       hiphop       3056
# 5    classical       2262
# 6  alternative       2028
# 7        world       1947
# 8       ruspop       1910
# 9       rusrap       1725

# %%
# Crear la nueva columna 'genre' agrupando los géneros con menos de 1000 oyentes como 'Other'
listeners_per_genre['genre'] = np.where(listeners_per_genre['listeners'] < 1725, 'Other', listeners_per_genre['genre'])
# Agrupar por 'genre' y sumar los oyentes
top_genres10 = listeners_per_genre.groupby('genre', as_index=False)['listeners'].sum()

# %%
print(top_genres10.head())
# Out:
#          genre  listeners
# 0        Other      22269
# 1  alternative       2028
# 2    classical       2262
# 3        dance       6367
# 4   electronic       5522

# %%
# Crear el gráfico de pastel
fig = px.pie(
    top_genres10,                     # DataFrame con los datos
    names='genre',                  # La columna para las categorías (géneros)
    values='listeners',             # La columna para los valores (oyentes)
    title='Distribución de Oyentes por Género'  # Título del gráfico
)
# Mostrar el gráfico
fig.show()

# %%
import plotly.express as px

# Ordenar el DataFrame por listeners
top_genres10 = top_genres10.sort_values('listeners', ascending=True)

# Crear el gráfico
fig = px.bar(top_genres10,
             x='listeners',
             y='genre',
             orientation='h',
             title='<b>TOP 10 GÉNEROS MUSICALES</b>',
             color='listeners',
             color_continuous_scale='thermal',
             text='listeners')

# Actualizar diseño (ajuste clave en yaxis)
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0.9)',
    paper_bgcolor='rgba(0,0,0,0.9)',
    title_font=dict(size=24, color='white', family="Jost"),
    font=dict(color='white'),
    xaxis=dict(title='<b>OYENTES</b>',
               showgrid=True,
               gridcolor='rgba(255,255,255,0.2)',
               title_font=dict(size=18, color='white')),
    yaxis=dict(title='',
               autorange="reversed",  # Esto mantiene el orden correcto
               tickfont=dict(size=14, color='white')),
)

# %% [markdown]
# ## Etapa 3. Prueba de hipótesis <a id='hypothesis'></a>

# %% [markdown]
# ### Hipótesis: comparar el comportamiento del usuario o la usuaria en las dos ciudades <a id='activity'></a>

# %% [markdown]
# La hipótesis afirma que existen diferencias en la forma en que los usuarios y las usuarias de Springfield y Shelbyville consumen música. Para comprobar esto, usa los datos de tres días de la semana: lunes, miércoles y viernes.
#
# * Agrupa a los usuarios y las usuarias por ciudad.
# * Compara el número de canciones que cada grupo reprodujo el lunes, el miércoles y el viernes.

# %% [markdown]
# Realiza cada cálculo por separado.
#
# El primer paso es evaluar la actividad del usuario en cada ciudad. Recuerda las etapas dividir-aplicar-combinar de las que hablamos anteriormente en la lección. Tu objetivo ahora es agrupar los datos por ciudad, aplicar el método apropiado para contar durante la etapa de aplicación y luego encontrar la cantidad de canciones reproducidas en cada grupo especificando la columna para obtener el recuento.
#
# A continuación se muestra un ejemplo de cómo debería verse el resultado final:
# `df.groupby(by='....')['column'].method()`Realiza cada cálculo por separado.
#
# Para evaluar la actividad de los usuarios y las usuarias en cada ciudad, agrupa los datos por ciudad y encuentra la cantidad de canciones reproducidas en cada grupo.

# %%
# Contar las canciones reproducidas en cada ciudad
print(df.groupby('city')['track'].count())
# Out:
# city
# Shelbyville    18512
# Springfield    42741
# Name: track, dtype: int64

# %% [markdown]
#     `Comenta tus observaciones aquí: En Springfield reproducen mas del doble de canciones que en Shelbyville`

# %% [markdown]
# Ahora agrupemos los datos por día de la semana y encontremos el número de canciones reproducidas el lunes, miércoles y viernes. Utiliza el mismo método que antes, pero ahora necesitamos una agrupación diferente.

# %%
# Calcular las canciones reproducidas en cada uno de los tres días
print(df.groupby('day')['track'].count())
# Out:
# day
# Friday       21840
# Monday       21354
# Wednesday    18059
# Name: track, dtype: int64

# %% [markdown]
# `Comenta tus observaciones aquí: El miercoles se ha escuchado menos musica que los dias lunes y viernes`

# %% [markdown]
# Ya sabes cómo contar entradas agrupándolas por ciudad o día. Ahora necesitas escribir una función que pueda contar entradas según ambos criterios simultáneamente.
#
# Crea la función `number_tracks()` para calcular el número de canciones reproducidas en un determinado día **y** ciudad. La función debe aceptar dos parámetros:
#
# - `day`: un día de la semana para filtrar. Por ejemplo, `'Monday'` (lunes).
# - `city`: una ciudad para filtrar. Por ejemplo, `'Springfield'`.
#
# Dentro de la función, aplicarás un filtrado consecutivo con indexación lógica.
#
# Primero filtra los datos por día y luego filtra la tabla resultante por ciudad.
#
# Después de filtrar los datos por dos criterios, cuenta el número de valores de la columna 'user_id' en la tabla resultante. Este recuento representa el número de entradas que estás buscando. Guarda el resultado en una nueva variable y devuélvelo desde la función.

# %%
# Declara la función number_tracks() con dos parámetros: day= y city=.
def number_tracks(df, day, city):
    # Almacena las filas del DataFrame donde el valor en la columna 'day' es igual al parámetro day=
    df = df[df['day'] == day]
    # Filtra las filas donde el valor en la columna 'city' es igual al parámetro city=
    df = df[df['city'] == city]
    # Extrae la columna 'user_id' de la tabla filtrada y aplica el método count()
    count = df['user_id'].count()
    # Devolve el número de valores de la columna 'user_id'
    return count

# %%
def numtracksfilter(df, day, city):
    df = df[(df['day'] == day) & (df['city'] == city)]
    return df['user_id'].count()

# %%
def numtracksgroup(df, day, city):
    df_grouped = df.groupby(['day', 'city'])['user_id'].count().reset_index()
    df_grouped.rename(columns={'user_id': 'listeners'}, inplace=True)
    df_grouped = df_grouped[(df_grouped['day'] == day) & (df_grouped['city'] == city)]
    return df_grouped['listeners']

# %%
number_tracks(df, 'Friday', 'Springfield')
# Out:
# 15945

# %% [markdown]
# Llama a `number_tracks()` seis veces, cambiando los valores de los parámetros para que recuperes los datos de ambas ciudades para cada uno de los tres días.

# %%
# El número de canciones reproducidas en Springfield el lunes
print(number_tracks(df, 'Monday', 'Springfield'))
# Out:
# 15740

# %%
# El número de canciones reproducidas en Shelbyville el lunes
print(number_tracks(df, 'Monday', 'Shelbyville'))
# Out:
# 5614

# %%
# El número de canciones reproducidas en Springfield el miércoles
print(number_tracks(df, 'Wednesday', 'Springfield'))
# Out:
# 11056

# %%
# El número de canciones reproducidas en Shelbyville el miércoles
print(number_tracks(df, 'Wednesday', 'Shelbyville'))
# Out:
# 7003

# %%
# El número de canciones reproducidas en Springfield el viernes
print(number_tracks(df, 'Friday', 'Springfield'))
# Out:
# 15945

# %%
# El número de canciones reproducidas en Shelbyville el viernes
print(number_tracks(df, 'Friday', 'Shelbyville'))
# Out:
# 5895

# %% [markdown]
# **Conclusiones**
#
# `La Hipótesis se acepta parcialmente ya que si bien la actividad difiere segun el dia y la ciudad, hay dias que la actividad en cada ciudad es bastante similar`

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# # Conclusiones <a id='end'></a>

# %% [markdown]
# `- La mayor cantidad de reproducciones se da el dia viernes en Springfield`
# `- La menor cantidad de reproducciones se da el dia lunes en Shelbyville`
# `- En Springfield se reproducen mas canciones que en Shelbyville`
# `- En Springfield se reproducen cantidades similares de canciones los dias lunes y viernes, mientras que los miercoles esta cifra disminuye`
# `- En Shelbyville se reproducen cantidades similares de canciones los dias lunes y viernes, mientras que los miercoles esta cifra aumenta`

# %% [markdown]
# [Volver a Contenidos](#back)
