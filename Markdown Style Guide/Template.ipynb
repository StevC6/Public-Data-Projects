# %% [markdown]
# <style>
# .alert-box {
#   padding: 14px 18px;
#   border-radius: 8px;
#   margin: 12px 0;
#   border-left: 6px solid;
#   font-family: Arial, sans-serif;
# }

# %% [markdown]
# # Contents <a id='home'></a>
#
# * [1 Html Blocks](#htmlblocks)
# * [2 Title Styles](#titlestyles)
# * [3 Sentences](#sentences)
# * [4 Emphasis](#emphasis)
# * [5 Lists](#lists)
# * [6 Links](#links)
# * [7 Code](#code)
# * [8 References](#references)
# * [9 Separator](#sep)

# %% [markdown]
# ## 1 Html blocks <a id='htmlblocks'></a>

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Success</b> <a class="tocSkip"></a> Success messages </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Warning alert</b> <a class="tocSkip"></a>
# Write warning alert here
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Danger alert</b> <a class="tocSkip"></a>
#
# Write danger alert here
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Info block</b> <a class="tocSkip"></a>
# Write your message here
# </div>

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 2 Title Styles <a id='titlestyles'></a>

# %% [markdown]
# # Main Title(H1)
# ## Section (H2)
# ### Subsection (H3)
# #### Details (H4)

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 3 Sentences <a id='sentences'></a>

# %% [markdown]
# First sentence.
#
# Second sentence.

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 4 Emphasis <a id='emphasis'></a>

# %% [markdown]
# **negrita**
# *cursiva*
# ***negrita y cursiva***

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 5 Lists <a id='lists'></a>

# %% [markdown]
# - Elemento
# - Elemento
#   - Sub-elemento
# 1. Paso 1
# 2. Paso 2
# 3. Paso 3

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 6 Links <a id='links'></a>

# %% [markdown]
# [Texto del enlace](https://ejemplo.com)

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 7 Code <a id='code'></a>

# %% [markdown]
# Aquí un `comando` o `variable`.
# ```python
# def sumar(a, b):
#     return a + b

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 8 References <a id='references'></a>

# %% [markdown]
# > Esto es una cita.
# > Se puede extender varias líneas.

# %% [markdown]
# [Return to contents](#home)

# %% [markdown]
# ## 9 Separate sections <a id='sep'></a>

# %% [markdown]
# ---

# %% [markdown]
# [Return to contents](#home)
